# %% [markdown]
# # BaceCRM Integration

# %%
import basecrm
import pandas as pd

# %%
client = basecrm.Client(access_token=auth_token)

# %%
pd_deals_list = pd.DataFrame(client.deals.list())

# %%
pd_deals_list
# Out:
#     contact_id            created_at  creator_id currency  \
# 0     64838755  2014-07-09T11:01:16Z      491825      USD
# 1     66844670  2014-08-03T23:38:45Z      491424      USD
# 2     65011064  2014-08-03T23:49:03Z      491424      USD
# 3     69944484  2014-08-06T18:44:54Z      491424      USD
# 4     72637389  2014-08-07T19:56:40Z      491424      USD
# 5     67136599  2014-08-08T18:34:46Z      491424      USD
# 6     69942173  2014-08-19T08:40:04Z      504811      USD
# 7     69946861  2014-08-20T06:51:33Z      491424      USD
# 8     92642108  2014-09-04T18:13:05Z      491424      USD
# 9     69942087  2014-09-08T10:15:30Z      511341      USD
# 10    69942090  2014-09-08T10:15:30Z      504811      USD
# 11    69942098  2014-09-08T10:15:36Z      511341      USD
# 12    69619391  2014-09-08T10:15:37Z      533837      USD
# 13    69942100  2014-09-08T10:15:38Z      504811      USD
# 14    69942102  2014-09-08T10:15:39Z      533837      USD
# ...

# %%
pd_leads_list_sources = pd.DataFrame(client.lead_sources.list())
pd_leads_list_sources
# Out:
#               created_at  creator_id      id                     name  \
# 0   2015-02-04T11:13:30Z      485683   10571  Website (Contact Sales)
# 1   2015-02-04T11:13:55Z      485683   10572                 Outbound
# 2   2015-03-23T13:12:41Z      603126   36675                   Events
# 3   2015-04-07T16:40:51Z      665756   42604                  Inbound
# 4   2015-04-22T09:59:50Z      665756   46187                 Referral
# 5   2015-05-07T09:51:52Z      552713   49609                  Support
# 6   2015-05-20T13:52:14Z      552713   56748             Social Media
# 7   2015-05-22T14:42:57Z      485683   57334         Whitepaper (MQL)
# 8   2015-05-22T14:43:02Z      485683   57335            Webinar (MQL)
# 9   2015-06-25T16:19:16Z      485683   73327           Direct Traffic
# 10  2015-07-09T08:13:51Z      485683   75681                Web store
# 11  2015-08-21T18:49:38Z      485683  110345             Inbound Call
# ...

# %%
pd_leads_list = pd.DataFrame(client.leads.list())
pd_leads_list
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-5ac6e2519ccd> in <module>()
# ----> 1 pd_leads_list = pd.DataFrame(client.leads.retrieve())
#       2 pd_leads_list
#
# TypeError: retrieve() missing 1 required positional argument: 'id'

# %%
pd_loss_reason_list = pd.DataFrame(client.loss_reasons.list())
pd_loss_reason_list
